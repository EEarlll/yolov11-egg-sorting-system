# %%
from ultralytics import FastSAM
from PIL import Image
from matplotlib import pyplot as plt
import numpy as np
import cv2
import os
import math
import random

# Load model
data = 'dataset/Images1/'
model = FastSAM('FastSAM-s.pt')

# %%
results = model(data, device="cpu", retina_masks=True, imgsz=1024, save=True)
# Out:
# image 1/58 c:\Users\earl\Python\object-size\dataset\Images1\image1.jpg: 1024x768 1 object, 689.9ms
# image 2/58 c:\Users\earl\Python\object-size\dataset\Images1\image10.jpg: 1024x800 26 objects, 846.7ms
# image 3/58 c:\Users\earl\Python\object-size\dataset\Images1\image11.jpg: 1024x800 23 objects, 621.7ms
# image 4/58 c:\Users\earl\Python\object-size\dataset\Images1\image12.jpg: 1024x800 24 objects, 1060.2ms
# image 5/58 c:\Users\earl\Python\object-size\dataset\Images1\image13.jpg: 1024x800 25 objects, 662.2ms
# image 6/58 c:\Users\earl\Python\object-size\dataset\Images1\image14.jpg: 1024x800 22 objects, 622.6ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 results = model(data, device="cpu", retina_masks=True, imgsz=1024, save=True)
#
# File c:\Users\earl\Python\object-size\.venv\Lib\site-packages\ultralytics\engine\model.py:176, in Model.__call__(self, source, stream, **kwargs)
#     147 def __call__(
#     148     self,
#     149     source: Union[str, Path, int, Image.Image, list, tuple, np.ndarray, torch.Tensor] = None,
#     150     stream: bool = False,
#     151     **kwargs,
#     152 ) -> list:
#     153     """
#     154     Alias for the predict method, enabling the model instance to be callable for predictions.
#     155
#    (...)
#     174         ...     print(f"Detected {len(r)} objects in image")
#     175     """
# --> 176     return self.predict(source, stream, **kwargs)
#
# File c:\Users\earl\Python\object-size\.venv\Lib\site-packages\ultralytics\models\fastsam\model.py:50, in FastSAM.predict(self, source, stream, bboxes, points, labels, texts, **kwargs)
#      32 """
#      33 Perform segmentation prediction on image or video source.
#      34
#    (...)
#      47     (list): Model predictions.
#      48 """
#      49 prompts = dict(bboxes=bboxes, points=points, labels=labels, texts=texts)
# ---> 50 return super().predict(source, stream, prompts=prompts, **kwargs)
#
# File c:\Users\earl\Python\object-size\.venv\Lib\site-packages\ultralytics\engine\model.py:554, in Model.predict(self, source, stream, predictor, **kwargs)
#     552 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     553     self.predictor.set_prompts(prompts)
# --> 554 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\earl\Python\object-size\.venv\Lib\site-packages\ultralytics\engine\predictor.py:173, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     171     return self.stream_inference(source, model, *args, **kwargs)
#     172 else:
# --> 173     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\earl\Python\object-size\.venv\Lib\site-packages\torch\utils\_contextlib.py:57, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      54         else:
#      55             # Pass the last request to the generator and get its response
#      56             with ctx_factory():
# ---> 57                 response = gen.send(request)
#      59 # We let the exceptions raised above by the generator's `.throw` or
#      60 # `.send` methods bubble up to our caller, except for StopIteration
#      61 except StopIteration as e:
#      62     # The generator informed us that it is done: take whatever its
#      63     # returned value (if any) was and indicate that we're done too
#      64     # by returning it (see docs for python's return-statement).
#
# File c:\Users\earl\Python\object-size\.venv\Lib\site-packages\ultralytics\engine\predictor.py:279, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     273     self.results[i].speed = {
#     274         "preprocess": profilers[0].dt * 1e3 / n,
#     275         "inference": profilers[1].dt * 1e3 / n,
#     276         "postprocess": profilers[2].dt * 1e3 / n,
#     277     }
#     278     if self.args.verbose or self.args.save or self.args.save_txt or self.args.show:
# --> 279         s[i] += self.write_results(i, Path(paths[i]), im, s)
#     281 # Print batch results
#     282 if self.args.verbose:
#
# File c:\Users\earl\Python\object-size\.venv\Lib\site-packages\ultralytics\engine\predictor.py:343, in BasePredictor.write_results(self, i, p, im, s)
#     341 # Add predictions to image
#     342 if self.args.save or self.args.show:
# --> 343     self.plotted_img = result.plot(
#     344         line_width=self.args.line_width,
#     345         boxes=self.args.show_boxes,
#     346         conf=self.args.show_conf,
#     347         labels=self.args.show_labels,
#     348         im_gpu=None if self.args.retina_masks else im[i],
#     349     )
#     351 # Save results
#     352 if self.args.save_txt:
#
# File c:\Users\earl\Python\object-size\.venv\Lib\site-packages\ultralytics\engine\results.py:533, in Results.plot(self, conf, line_width, font_size, font, pil, img, im_gpu, kpt_radius, kpt_line, labels, boxes, masks, probs, show, save, filename, color_mode)
#     519         im_gpu = (
#     520             torch.as_tensor(img, dtype=torch.float16, device=pred_masks.data.device)
#     521             .permute(2, 0, 1)
#    (...)
#     524             / 255
#     525         )
#     526     idx = (
#     527         pred_boxes.id
#     528         if pred_boxes.id is not None and color_mode == "instance"
#    (...)
#     531         else reversed(range(len(pred_masks)))
#     532     )
# --> 533     annotator.masks(pred_masks.data, colors=[colors(x, True) for x in idx], im_gpu=im_gpu)
#     535 # Plot Detect results
#     536 if pred_boxes is not None and show_boxes:
#
# File c:\Users\earl\Python\object-size\.venv\Lib\site-packages\ultralytics\utils\plotting.py:408, in Annotator.masks(self, masks, colors, im_gpu, alpha, retina_masks)
#     405 masks = masks.unsqueeze(3)  # shape(n,h,w,1)
#     406 masks_color = masks * (colors * alpha)  # shape(n,h,w,3)
# --> 408 inv_alpha_masks = (1 - masks * alpha).cumprod(0)  # shape(n,h,w,1)
#     409 mcs = masks_color.max(dim=0).values  # shape(n,h,w,3)
#     411 im_gpu = im_gpu.flip(dims=[0])  # flip channel
#
# File c:\Users\earl\Python\object-size\.venv\Lib\site-packages\torch\_tensor.py:33, in _handle_torch_function_and_wrap_type_error_to_not_implemented.<locals>.wrapped(*args, **kwargs)
#      30 def _handle_torch_function_and_wrap_type_error_to_not_implemented(f):
#      31     assigned = functools.WRAPPER_ASSIGNMENTS
# ---> 33     @functools.wraps(f, assigned=assigned)
#      34     def wrapped(*args, **kwargs):
#      35         try:
#      36             # See https://github.com/pytorch/pytorch/issues/75462
#      37             if has_torch_function(args):
#
# KeyboardInterrupt:
